# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanqwrt/MMVSULAB1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

x = [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
y = [1097000, 1097000, 1096000, 1092000, 1092000, 1094000, 1082000, 1084000, 1088900, 1091200, 1088800, 1042437, 1043306, 1040623, 1036026, 1029616, 1022575, 1021458, 1024842, 1065602, 1072291, 1077719, 1096702, 1105667, 1121560, 1120547, 1124226, 1128787, 1144809,1144909, 1145009]

plt.plot(x, y)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
def dydt(x,t):
  k = 0.173
  return k*x
t = np.linspace(0,0.5,31)

solve = odeint(dydt, 1050000, t=t)
solve = solve.flatten()
m = [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
n = [1097000, 1097000, 1096000, 1092000, 1092000, 1094000, 1082000, 1084000, 1088900, 1091200, 1088800, 1042437, 1043306, 1040623, 1036026, 1029616, 1022575, 1021458, 1024842, 1065602, 1072291, 1077719, 1096702, 1105667, 1121560, 1120547, 1124226, 1128787, 1144809,1144909, 1145009]

# %matplotlib inline


plt.plot(m, solve, label = r"x′=kx")
plt.plot(m, n)
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

def dydt(x,t):
  return x*k(x)/2500000000

def k(x):
  a=-99000
  b=1
  return (a*x-b)

t = np.linspace(0,0.1,31)

solve = odeint(dydt, 2397000, t=t)
solve = solve.flatten()
m = [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
n = [1097000, 1097000, 1096000, 1092000, 1092000, 1094000, 1082000, 1084000, 1088900, 1091200, 1088800, 1042437, 1043306, 1040623, 1036026, 1029616, 1022575, 1021458, 1024842, 1065602, 1072291, 1077719, 1096702, 1105667, 1121560, 1120547, 1124226, 1128787, 1144809,1144909, 1145009]

# %matplotlib inline
plt.plot(m,solve,label=r"x′=k(x)x")
plt.plot(m, n)
plt.grid(True)
plt.legend()
plt.show()
